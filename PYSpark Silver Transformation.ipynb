-- %%
%python
catalog = "workspace"

for layer, comment in [
    ("silver", "limpeza e padronizacao- dados validados e tipados"),
    ("gold", "camada analitica - agregacoes")
]:
    # Use a tecla TAB uma única vez para alinhar os comandos abaixo
    spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog}.{layer} COMMENT '{comment}'")
    print(f"ok {catalog}.{layer}")
